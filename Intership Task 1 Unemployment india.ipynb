# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="D:/Ai/Data Analyst Internn/Unemployment India/Unemployment in India.csv"
df_unemp=pd.read_csv(path,parse_dates=['Date'], dayfirst=True)
df_unemp.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %%
df_unemp.describe()
# Out:
#                                 Date  Estimated Unemployment Rate (%)  \
# count                            740                       740.000000
# mean   2019-12-12 18:36:58.378378496                        11.787946
# min              2019-05-31 00:00:00                         0.000000
# 25%              2019-08-31 00:00:00                         4.657500
# 50%              2019-11-30 00:00:00                         8.350000
# 75%              2020-03-31 00:00:00                        15.887500
# max              2020-06-30 00:00:00                        76.740000
# std                              NaN                        10.721298
#
#        Estimated Employed  Estimated Labour Participation Rate (%)
# count        7.400000e+02                               740.000000
# mean         7.204460e+06                                42.630122
# min          4.942000e+04                                13.330000
# 25%          1.190404e+06                                38.062500
# 50%          4.744178e+06                                41.160000
# 75%          1.127549e+07                                45.505000
# max          4.577751e+07                                72.570000
# std          8.087988e+06                                 8.111094

# %%
df_unemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 41.4+ KB

# %%
df_unemp.shape
# Out:
# (754, 7)

# %%
df_unemp.isnull()
# Out:
#      Region   Date  Frequency  Estimated Unemployment Rate (%)  \
# 0     False  False      False                            False
# 1     False  False      False                            False
# 2     False  False      False                            False
# 3     False  False      False                            False
# 4     False  False      False                            False
# ..      ...    ...        ...                              ...
# 749   False  False      False                            False
# 750   False  False      False                            False
# 751   False  False      False                            False
# 752   False  False      False                            False
# 753   False  False      False                            False
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0                 False                                    False  False
# 1                 False                                    False  False
# 2                 False                                    False  False
# 3                 False                                    False  False
# 4                 False                                    False  False
# ..                  ...                                      ...    ...
# 749               False                                    False  False
# 750               False                                    False  False
# 751               False                                    False  False
# 752               False                                    False  False
# 753               False                                    False  False
#
# [754 rows x 7 columns]

# %% [markdown]
# # Clean Data

# %%
df_unemp.dropna(inplace=True)

# %%
# Checking For Duplicates

df_unemp[df_unemp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region, Date, Frequency, Estimated Unemployment Rate (%), Estimated Employed, Estimated Labour Participation Rate (%), Area]
# Index: []

# %%
df_unemp["Region"].value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %% [markdown]
# ## Check that all null values removed

# %%
df_unemp.isna().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %% [markdown]
# ## Visualize Outliers

# %%
df_unemp.plot(subplots=True,figsize=(15,10))
plt.show()

# %%
df_unemp.describe().round(2)
# Out:
#                                 Date  Estimated Unemployment Rate (%)  \
# count                            740                           740.00
# mean   2019-12-12 18:36:58.378378496                            11.79
# min              2019-05-31 00:00:00                             0.00
# 25%              2019-08-31 00:00:00                             4.66
# 50%              2019-11-30 00:00:00                             8.35
# 75%              2020-03-31 00:00:00                            15.89
# max              2020-06-30 00:00:00                            76.74
# std                              NaN                            10.72
#
#        Estimated Employed  Estimated Labour Participation Rate (%)
# count              740.00                                   740.00
# mean           7204460.03                                    42.63
# min              49420.00                                    13.33
# 25%            1190404.50                                    38.06
# 50%            4744178.50                                    41.16
# 75%           11275489.50                                    45.50
# max           45777509.00                                    72.57
# std            8087988.43                                     8.11

# %%
df_unemp.boxplot('Estimated Unemployment Rate (%)')
# Out:
# <Axes: >

# %%
df_unemp[df_unemp["Estimated Unemployment Rate (%)"] >32 ]
# Out:
#                Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 37              Bihar 2020-04-30   Monthly                            45.09
# 38              Bihar 2020-05-31   Monthly                            47.26
# 105           Haryana 2020-04-30   Monthly                            41.61
# 106           Haryana 2020-05-31   Monthly                            34.22
# 107           Haryana 2020-06-30   Monthly                            35.57
# 144         Jharkhand 2020-04-30   Monthly                            41.72
# 145         Jharkhand 2020-05-31   Monthly                            55.10
# 158         Karnataka 2020-04-30   Monthly                            33.17
# 242        Puducherry 2020-04-30   Monthly                            74.51
# 255            Punjab 2020-05-31   Monthly                            40.59
# 287        Tamil Nadu 2020-04-30   Monthly                            53.19
# 288        Tamil Nadu 2020-05-31   Monthly                            38.73
# 302         Telangana 2020-05-31   Monthly                            34.01
# 315           Tripura 2020-04-30   Monthly                            43.64
# 384    Andhra Pradesh 2020-04-30   Monthly                            32.30
# 412             Bihar 2020-04-30   Monthly                            58.77
# 413             Bihar 2020-05-31   Monthly                            37.87
# 453             Delhi 2020-05-31   Monthly                            45.78
# 492           Haryana 2020-04-30   Monthly                            46.89
# 493           Haryana 2020-05-31   Monthly                            38.46
# 507  Himachal Pradesh 2020-05-31   Monthly                            50.00
# 530         Jharkhand 2020-04-30   Monthly                            61.48
# 531         Jharkhand 2020-05-31   Monthly                            70.17
# 573    Madhya Pradesh 2020-05-31   Monthly                            40.49
# 627        Puducherry 2020-04-30   Monthly                            76.74
# 628        Puducherry 2020-05-31   Monthly                            75.00
# 655         Rajasthan 2020-04-30   Monthly                            35.53
# 681        Tamil Nadu 2020-04-30   Monthly                            45.55
# 696         Telangana 2020-05-31   Monthly                            36.57
# 698           Tripura 2019-05-31   Monthly                            34.69
# 701           Tripura 2019-08-31   Monthly                            33.45
# 702           Tripura 2019-09-30   Monthly                            33.57
# 705           Tripura 2019-12-31   Monthly                            33.48
# 706           Tripura 2020-01-31   Monthly                            34.37
# 707           Tripura 2020-02-29   Monthly                            33.88
# 709           Tripura 2020-04-30   Monthly                            34.88
# 724     Uttar Pradesh 2020-05-31   Monthly                            32.06
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 37           14645275.0                                    38.63  Rural
# 38           14050319.0                                    38.50  Rural
# 105           4041050.0                                    49.85  Rural
# 106           3914193.0                                    42.78  Rural
# 107           4357835.0                                    48.53  Rural
# 144           4280434.0                                    36.92  Rural
# 145           3315038.0                                    37.03  Rural
# 158           9330400.0                                    43.25  Rural
# 242             49420.0                                    46.79  Rural
# 255           3727366.0                                    41.14  Rural
# 287           5086200.0                                    33.05  Rural
# 288           5768342.0                                    28.60  Rural
# 302           7508747.0                                    61.00  Rural
# 315            675083.0                                    52.63  Rural
# 384           2544084.0                                    26.97  Urban
# 412           1400962.0                                    34.94  Urban
# 413           2207026.0                                    36.45  Urban
# 453           2343783.0                                    28.28  Urban
# 492           1606580.0                                    35.48  Urban
# 493           2013083.0                                    38.27  Urban
# 507            134868.0                                    43.55  Urban
# 530           1054829.0                                    39.92  Urban
# 531            830347.0                                    40.49  Urban
# 573           3879934.0                                    35.49  Urban
# 627             68122.0                                    35.54  Urban
# 628             64538.0                                    31.25  Urban
# 655           2932923.0                                    29.57  Urban
# 681           4632967.0                                    26.17  Urban
# 696           3108830.0                                    37.63  Urban
# 698            423127.0                                    69.50  Urban
# 701            368977.0                                    59.07  Urban
# 702            418043.0                                    66.90  Urban
# 705            399427.0                                    63.41  Urban
# 706            450155.0                                    72.26  Urban
# 707            415339.0                                    66.04  Urban
# 709            296431.0                                    47.65  Urban
# 724          11111486.0                                    41.10  Urban

# %%
x=df_unemp[df_unemp["Estimated Unemployment Rate (%)"] >32 ]
x.shape
# Out:
# (37, 7)

# %%
per75th=df_unemp["Estimated Unemployment Rate (%)"].quantile(0.75)
per75th.round(2)
# Out:
# 15.89

# %%
per25th=df_unemp["Estimated Unemployment Rate (%)"].quantile(0.25)
per25th.round(2)
# Out:
# 4.66

# %%
IQR_unem=per75th-per25th
IQR_unem
# Out:
# 11.23

# %%
upper = per75th +(1.5*IQR_unem)

lower = per25th -(1.5*IQR_unem)

print(upper,lower)
# Out:
# 32.7325 -12.187499999999998

# %%
outliers=df_unemp[(df_unemp["Estimated Unemployment Rate (%)"]> upper) | (df_unemp["Estimated Unemployment Rate (%)"]<lower) ]
outliers.shape
# Out:
# (35, 7)

# %%
# outliers  may help in predictions

# %% [markdown]
# ## Visualize Data

# %%
avg_unemployment_rate=df_unemp.groupby('Region')['Estimated Unemployment Rate (%)'].mean()

# %%
avg_unemployment_rate
# Out:
# Region
# Andhra Pradesh       7.477143
# Assam                6.428077
# Bihar               18.918214
# Chandigarh          15.991667
# Chhattisgarh         9.240357
# Delhi               16.495357
# Goa                  9.274167
# Gujarat              6.663929
# Haryana             26.283214
# Himachal Pradesh    18.540357
# Jammu & Kashmir     16.188571
# Jharkhand           20.585000
# Karnataka            6.676071
# Kerala              10.123929
# Madhya Pradesh       7.406429
# Maharashtra          7.557500
# Meghalaya            4.798889
# Odisha               5.657857
# Puducherry          10.215000
# Punjab              12.031071
# Rajasthan           14.058214
# Sikkim               7.249412
# Tamil Nadu           9.284286
# Telangana            7.737857
# Tripura             28.350357
# Uttar Pradesh       12.551429
# Uttarakhand          6.582963
# West Bengal          8.124643
# Name: Estimated Unemployment Rate (%), dtype: float64

# %% [markdown]
# ### Average Unemployment Rate by Region

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=avg_unemployment_rate.index ,y=avg_unemployment_rate.values,color='#0095c7')
plt.xlabel('Region')
plt.ylabel('Unemployment percentage')
plt.title('Average Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# ### Relationship Between Unemployment Rate and Labour Participation Rate and Estimated Employed

# %%
sns.pairplot(df_unemp,height=4)
plt.show()
# Out:
# F:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
total_nums=df_unemp.groupby("Date")["Estimated Unemployment Rate (%)"].sum()
total_nums
# Out:
# Date
# 2019-05-31     479.21
# 2019-06-30     502.38
# 2019-07-31     487.83
# 2019-08-31     510.81
# 2019-09-30     470.69
# 2019-10-31     544.55
# 2019-11-30     542.76
# 2019-12-31     503.36
# 2020-01-31     527.39
# 2020-02-29     528.13
# 2020-03-31     556.43
# 2020-04-30    1205.72
# 2020-05-31    1268.64
# 2020-06-30     595.18
# Name: Estimated Unemployment Rate (%), dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x="Date", y="Estimated Unemployment Rate (%)", data=df_unemp,hue="Area")
plt.title("Total Unemployment Rate Over Time ")
plt.xlabel("Date")
plt.ylabel("Unemployment Percentage (%)")
plt.show()
# Out:
# F:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Unemployment Rate by region

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x=df_unemp["Region"] ,y=df_unemp["Estimated Unemployment Rate (%)"],hue=df_unemp["Area"])
plt.xlabel('Region')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x=df_unemp["Region"] ,y=df_unemp["Estimated Labour Participation Rate (%)"],hue=df_unemp["Area"])
plt.xlabel('Region')
plt.ylabel('Labour Participation Rate')
plt.title('Labour Participation Rate by Region')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
unemployment_rate=pd.pivot_table(data=df_unemp,index="Date",columns="Region",values="Estimated Unemployment Rate (%)")

# %%
unemployment_rate
# Out:
# Region      Andhra Pradesh   Assam   Bihar  Chandigarh  Chhattisgarh   Delhi  \
# Date
# 2019-05-31           4.870   6.080  14.585       18.35         9.795  12.435
# 2019-06-30           3.425   7.485  11.745       12.40         9.265  11.045
# 2019-07-31           4.695   3.735  14.925       21.80         6.355  12.875
# 2019-08-31           3.965   8.090  14.330        9.52         5.465  15.350
# 2019-09-30           5.590   6.860  14.665       20.14         8.895  16.545
# 2019-10-31           4.110   7.910  13.265       13.99         8.615  14.125
# 2019-11-30           5.830   5.485  15.010       22.05         5.545  13.610
# 2019-12-31           6.130   5.020  12.535        8.33         4.840  14.020
# 2020-01-31           5.975   5.765  14.910       20.00         9.450  17.965
# 2020-02-29           5.785   6.620  12.360       16.67         8.840  14.335
# 2020-03-31           6.970   7.055  15.560       21.43         7.760  16.135
# 2020-04-30          24.295   8.370  51.930         NaN        10.065  18.600
# 2020-05-31          19.685  10.075  42.565         NaN        15.870  34.270
# 2020-06-30           3.355   1.710  16.470        7.22        18.605  19.625
#
# Region         Goa  Gujarat  Haryana  Himachal Pradesh  ...  Puducherry  \
# Date                                                    ...
# 2019-05-31   2.830    3.485   19.605            12.280  ...       0.625
# 2019-06-30   9.390    5.540   21.750            16.430  ...       0.000
# 2019-07-31  11.630    4.865   20.835            21.050  ...       0.000
# 2019-08-31   3.440    3.950   27.565            21.520  ...       6.900
# 2019-09-30   3.385    6.125   21.600            13.990  ...       0.610
# 2019-10-31   9.760    5.180   22.605            19.790  ...       1.175
# 2019-11-30  24.455    6.105   21.825            25.065  ...       0.685
# 2019-12-31   9.880    4.585   26.605            22.390  ...       3.600
# 2020-01-31   8.150    5.585   21.725            17.410  ...       0.575
# 2020-02-29   2.155    6.340   25.240            21.365  ...       1.760
# 2020-03-31   4.760    6.490   25.530            22.075  ...       1.465
# 2020-04-30  13.835   18.970   44.250             2.415  ...      75.625
# 2020-05-31  20.000   13.100   36.340            37.820  ...      75.000
# 2020-06-30     NaN    2.975   32.490             5.965  ...       4.550
#
# Region      Punjab  Rajasthan  Sikkim  Tamil Nadu  Telangana  Tripura  \
# Date
# 2019-05-31  11.330      8.825   8.200       0.930      1.875   31.970
# 2019-06-30  12.690     14.030   7.760       1.240      3.675   26.115
# 2019-07-31  10.625     10.685   2.560       4.595      3.090   24.140
# 2019-08-31   9.340     13.605   4.820       6.220      2.795   29.470
# 2019-09-30  12.140      9.040   4.810       1.785      5.840   31.900
# 2019-10-31  13.155     13.840   7.580       1.295      7.015   27.105
# 2019-11-30   8.730     12.385   8.575       2.555      5.850   26.200
# 2019-12-31   9.050     16.000   4.185       5.890      2.785   30.005
# 2020-01-31  11.685     13.410     NaN       1.615      5.755   33.140
# 2020-02-29  11.200     15.750     NaN       2.240      7.880   30.050
# 2020-03-31  10.240     14.005  20.450       6.410      5.865   28.650
# 2020-04-30   2.410     23.890   2.885      49.370      7.505   39.260
# 2020-05-31  30.565     17.900  19.750      32.340     35.290   15.745
# 2020-06-30  15.275     13.450   4.220      13.495     13.110   23.155
#
# Region      Uttar Pradesh  Uttarakhand  West Bengal
# Date
# 2019-05-31         12.330        5.400        6.635
# 2019-06-30         11.375        4.670        6.615
# 2019-07-31         10.495        6.340        6.765
# 2019-08-31         13.100        6.770        6.425
# 2019-09-30         10.015        6.545        6.525
# 2019-10-31         10.265        4.775        7.305
# 2019-11-30          9.125        5.950        6.220
# 2019-12-31         10.400        5.955        6.515
# 2020-01-31          9.200        6.545        7.030
# 2020-02-29          9.885        5.065        5.665
# 2020-03-31         10.845        8.150        6.845
# 2020-04-30         23.430        8.420       16.975
# 2020-05-31         24.475       10.465       16.825
# 2020-06-30         10.780        7.895        7.400
#
# [14 rows x 28 columns]
