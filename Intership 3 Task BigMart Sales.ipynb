# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path="D:\Ai\Data Analyst Internn\CognoRise internship\BigMart Sales\Train.csv"
df_sales=pd.read_csv(path,parse_dates=["Outlet_Establishment_Year"],date_format="%Y")

# %%
df_sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                1999-01-01      Medium               Tier 1
# 1                2009-01-01      Medium               Tier 3
# 2                1999-01-01      Medium               Tier 1
# 3                1998-01-01         NaN               Tier 3
# 4                1987-01-01        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df_sales.shape
# Out:
# (8523, 12)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   datetime64[ns]
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 799.2+ KB

# %%
df_sales.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5270           NCA06       20.500          Low Fat         0.143284
# 6997           FDU52          NaN          Low Fat         0.111655
# 113            FDX34          NaN          Low Fat         0.071637
# 1371           FDD52       18.250          Regular         0.184042
# 353            DRI01        7.970          Low Fat         0.034453
# 1361           FDX36        9.695          Regular         0.129009
# 3822           FDA44          NaN          Low Fat         0.052965
# 5754           FDH47       13.500          Regular         0.128792
# 2372           NCX06       17.600          Low Fat         0.015776
# 4485           NCV29       11.800          Low Fat         0.022844
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5270              Household   37.9190            OUT046
# 6997           Frozen Foods  157.0630            OUT019
# 113             Snack Foods  121.7098            OUT027
# 1371                  Dairy  110.1570            OUT018
# 353             Soft Drinks  174.0422            OUT046
# 1361           Baking Goods  226.9404            OUT017
# 3822  Fruits and Vegetables   57.7930            OUT027
# 5754          Starchy Foods   95.4068            OUT035
# 2372              Household  179.1976            OUT017
# 4485     Health and Hygiene  177.8686            OUT046
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5270                1997-01-01       Small               Tier 1
# 6997                1985-01-01       Small               Tier 1
# 113                 1985-01-01      Medium               Tier 3
# 1371                2009-01-01      Medium               Tier 3
# 353                 1997-01-01       Small               Tier 1
# 1361                2007-01-01         NaN               Tier 2
# 3822                1985-01-01      Medium               Tier 3
# 5754                2004-01-01       Small               Tier 2
# 2372                2007-01-01         NaN               Tier 2
# 4485                1997-01-01       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 5270  Supermarket Type1           183.0950
# 6997      Grocery Store           312.9260
# 113   Supermarket Type3          4097.3332
# 1371  Supermarket Type2          1867.5690
# 353   Supermarket Type1          2586.6330
# 1361  Supermarket Type1          2700.4848
# 3822  Supermarket Type3          1754.3830
# 5754  Supermarket Type1          1944.1360
# 2372  Supermarket Type1          3803.0496
# 4485  Supermarket Type1          4621.9836

# %%
df_sales.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  \
# count  7060.000000      8523.000000  8523.000000
# mean     12.857645         0.066132   140.992782
# min       4.555000         0.000000    31.290000
# 25%       8.773750         0.026989    93.826500
# 50%      12.600000         0.053931   143.012800
# 75%      16.850000         0.094585   185.643700
# max      21.350000         0.328391   266.888400
# std       4.643456         0.051598    62.275067
#
#            Outlet_Establishment_Year  Item_Outlet_Sales
# count                           8523        8523.000000
# mean   1997-10-31 13:12:33.959873408        2181.288914
# min              1985-01-01 00:00:00          33.290000
# 25%              1987-01-01 00:00:00         834.247400
# 50%              1999-01-01 00:00:00        1794.331000
# 75%              2004-01-01 00:00:00        3101.296400
# max              2009-01-01 00:00:00       13086.964800
# std                              NaN        1706.499616

# %%
for col in df_sales.columns :
    print( f"{col} unique values is:\n {df_sales[col].unique()} \n ---------------- " )
# Out:
# Item_Identifier unique values is:
#  ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05
['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
#  ----------------
# Item_Visibility unique values is:
#  [0.0160473  0.01927822 0.01676007 ... 0.03518627 0.14522065 0.04487828]
#  ----------------
# Item_Type unique values is:
#  ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
#  ----------------
# Item_MRP unique values is:
#  [249.8092  48.2692 141.618  ...  57.5904 214.5218  75.467 ]
#  ----------------
# Outlet_Identifier unique values is:
#  ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
#  ----------------
# Outlet_Establishment_Year unique values is:
#  <DatetimeArray>
# ['1999-01-01 00:00:00', '2009-01-01 00:00:00', '1998-01-01 00:00:00',
#  '1987-01-01 00:00:00', '1985-01-01 00:00:00', '2002-01-01 00:00:00',
#  '2007-01-01 00:00:00', '1997-01-01 00:00:00', '2004-01-01 00:00:00']
# Length: 9, dtype: datetime64[ns]
#  ----------------
# Outlet_Size unique values is:
#  ['Medium' nan 'High' 'Small']
#  ----------------
# Outlet_Location_Type unique values is:
#  ['Tier 1' 'Tier 3' 'Tier 2']
#  ----------------
# Outlet_Type unique values is:
#  ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']
#  ----------------
# Item_Outlet_Sales unique values is:
#  [3735.138   443.4228 2097.27   ... 7182.6504 3608.636  2778.3834]
#  ----------------

# %% [markdown]
# # Clean Data

# %%
df_sales.duplicated().sum()
# Out:
# 0

# %%
df_sales.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#normalize the numbers
((df_sales.isna().sum())/df_sales.shape[0])*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
df_sales.shape
# Out:
# (8523, 12)

# %%
df_sales["Item_Weight"].fillna(df_sales["Item_Weight"].mean(),inplace=True)

# %%
df_sales["Item_Weight"].isna().sum()
# Out:
# 0

# %%
df_sales.dropna(inplace=True)
df_sales.shape
# Out:
# (6113, 12)

# %%
df_sales["Outlet_Size"].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
df_sales["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'reg', 'LF'], dtype=object)

# %%
df_sales["Item_Fat_Content"]=df_sales["Item_Fat_Content"].replace({"low fat":"Low Fat","LF":"Low Fat","reg":"Regular"})

# %%
df_sales["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# # Handling Outliers

# %%
# Visualize Trends 

df_sales.plot(subplots=True,figsize=(16,6))
plt.show()

# %%
per25=df_sales["Item_Visibility"].quantile(0.25)
per75=df_sales["Item_Visibility"].quantile(0.75)
print(per25,per75)
# Out:
# 0.026681262 0.092834313

# %%
iqr=per75-per25
iqr
# Out:
# 0.066153051

# %%
upper=per75+(iqr*1.5)
lower=per25-(iqr*1.5)
upper,lower
# Out:
# (0.1920638895, -0.0725483145)

# %%
df_sales=df_sales[(df_sales["Item_Visibility"] <= upper )&(df_sales["Item_Visibility"]>=lower)]
df_sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750          Regular         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                   1999-01-01      Medium               Tier 1
# 1                   2009-01-01      Medium               Tier 3
# 2                   1999-01-01      Medium               Tier 1
# 4                   1987-01-01        High               Tier 3
# 5                   2009-01-01      Medium               Tier 3
# ...                        ...         ...                  ...
# 8517                1997-01-01       Small               Tier 1
# 8518                1987-01-01        High               Tier 3
# 8520                2004-01-01       Small               Tier 2
# 8521                2009-01-01      Medium               Tier 3
# 8522                1997-01-01       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [6032 rows x 12 columns]

# %%
per25=df_sales["Item_Outlet_Sales"].quantile(0.25)
per75=df_sales["Item_Outlet_Sales"].quantile(0.75)
print(per25,per75)
# Out:
# 1006.6896 3292.381

# %%
iqr=per75-per25
iqr
# Out:
# 2285.6913999999997

# %%
upper=per75+(iqr*1.5)
lower=per25-(iqr*1.5)
upper,lower
# Out:
# (6720.918099999999, -2421.8474999999994)

# %%
df_sales=df_sales[(df_sales["Item_Outlet_Sales"] <= upper )&(df_sales["Item_Outlet_Sales"]>=lower)]
df_sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750          Regular         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                   1999-01-01      Medium               Tier 1
# 1                   2009-01-01      Medium               Tier 3
# 2                   1999-01-01      Medium               Tier 1
# 4                   1987-01-01        High               Tier 3
# 5                   2009-01-01      Medium               Tier 3
# ...                        ...         ...                  ...
# 8517                1997-01-01       Small               Tier 1
# 8518                1987-01-01        High               Tier 3
# 8520                2004-01-01       Small               Tier 2
# 8521                2009-01-01      Medium               Tier 3
# 8522                1997-01-01       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [5897 rows x 12 columns]

# %%
df_sales.plot(subplots=True,figsize=(16,6))
plt.show()

# %%
df_sales.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(16,6))
sns.pairplot(df_sales)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df_sales,x="Outlet_Establishment_Year",y="Item_Outlet_Sales")
plt.title("Outlet Sales over Years")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.violinplot(data=df_sales,x="Item_Fat_Content",y="Item_MRP",width=0.3,palette=["red","green"])
plt.title("Comparison of Distribution Fat Content Categories Across Item MRP ")
plt.show()

# %%
plt.figure(figsize=(7,9))
sns.barplot(data=df_sales,x="Item_Fat_Content",y="Item_MRP",width=0.25,palette=["red","green"],)
plt.title("Comparison of   Item MRP's Mean  Across Fat Content Categories  ")

plt.show()

# %%
plt.figure(figsize=(3,4))
sns.histplot(df_sales["Item_Fat_Content"])
plt.title("Outlet Sales over Years")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.histplot(df_sales["Item_Visibility"],kde=True)
plt.title("Distribution of Item Visibility")
plt.show()

# %%
df_sales.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6))
sns.histplot(df_sales["Outlet_Size"])
plt.title("Outlet ٍSize Count")
plt.show()

# %%
df_sales["Outlet_Location_Type"].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
plt.figure(figsize=(16,6))
sns.histplot(df_sales["Outlet_Location_Type"])
plt.title("Outlet Location Type Count")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=df_sales["Outlet_Location_Type"],y=df_sales["Item_Outlet_Sales"])
plt.title("Item Outlet Sales by Loction Type")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.kdeplot(x=df_sales["Item_Visibility"],y=df_sales["Item_Outlet_Sales"])
plt.show()

# %%
df_sales.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')
